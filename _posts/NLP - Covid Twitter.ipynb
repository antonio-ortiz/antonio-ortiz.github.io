# %% [markdown]
# ## Analysis of Covid Tweets with NLP

# %% [markdown]
# Question: How seriously are Twitter users from each country taking Covid-19?

# %%
import pandas as pd
import numpy as np
import us
import re
import nltk
import sklearn
from nltk.stem import PorterStemmer
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB

# %%
data = pd.read_csv("covid19_tweets.csv")

# %%
data.iloc[16]
# Out:
# user_name                                              ChennaiCityNow
# user_location                                                     NaN
# user_description    Individual tweeting about significant happenin...
# user_created                                      2009-04-26 09:38:11
# user_followers                                                   3987
# user_friends                                                       53
# user_favourites                                                   749
# user_verified                                                   False
# date                                              2020-07-25 12:26:44
# text                July 25 #COVID19 update\n#TamilNadu - 6988\nDi...
# hashtags                          ['COVID19', 'TamilNadu', 'chennai']
# source                                             Twitter for iPhone
# is_retweet                                                      False
# Name: 16, dtype: object

# %%
data_1 = data[['user_location', 'user_description', 'user_verified', 'date', 'text', 'hashtags', 'is_retweet']]

# %%
data_1.user_location = data_1.user_location.str.split(',').str[-1].astype(str).str.strip().apply(us.states.lookup).astype(str)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
data_1
# Out:
#        user_location                                   user_description  \
# 0               None  wednesday addams as a disney princess keepin i...
# 1           New York  Husband, Father, Columnist & Commentator. Auth...
# 2           Kentucky  #Christian #Catholic #Conservative #Reagan #Re...
# 3               None  #Browns #Indians #ClevelandProud #[]_[] #Cavs ...
# 4               None  🖊️Official Twitter handle of Department of Inf...
# ...              ...                                                ...
# 179103          None    Animal Scientist|| Muslim|| Real Madrid/Chelsea
# 179104          None  When your cat has more baking soda than Ninja ...
# 179105          None  ⚒️ The Architects of Free Trade ⚒️ Really Did ...
# 179106          None  Global UX UI Visual Designer. StoryTeller, Mus...
# 179107          None  TOKELO SEKHOPA | TUKY II | LAST BORN | EISH TU...
#
#         user_verified                 date  \
# 0               False  2020-07-25 12:27:21
# 1                True  2020-07-25 12:27:17
# 2               False  2020-07-25 12:27:14
# 3               False  2020-07-25 12:27:10
# 4               False  2020-07-25 12:27:08
# ...               ...                  ...
# 179103          False  2020-08-29 19:44:21
# 179104          False  2020-08-29 19:44:16
# 179105          False  2020-08-29 19:44:15
# 179106          False  2020-08-29 19:44:14
# 179107          False  2020-08-29 19:44:08
#
#                                                      text  \
# 0       If I smelled the scent of hand sanitizers toda...
# 1       Hey @Yankees @YankeesPR and @MLB - wouldn't it...
# 2       @diane3443 @wdunlap @realDonaldTrump Trump nev...
# 3       @brookbanktv The one gift #COVID19 has give me...
# 4       25 July : Media Bulletin on Novel #CoronaVirus...
# ...                                                   ...
# 179103  Thanks @IamOhmai for nominating me for the @WH...
# 179104  2020! The year of insanity! Lol! #COVID19 http...
# 179105  @CTVNews A powerful painting by Juan Lucena. I...
# 179106  More than 1,200 students test positive for #CO...
# 179107  I stop when I see a Stop\n\n@SABCNews\n@Izinda...
#
#                                  hashtags  is_retweet
# 0                                     NaN       False
# 1                                     NaN       False
# 2                             ['COVID19']       False
# 3                             ['COVID19']       False
# 4       ['CoronaVirusUpdates', 'COVID19']       False
# ...                                   ...         ...
# 179103                      ['WearAMask']       False
# 179104                        ['COVID19']       False
# 179105                                NaN       False
# 179106                        ['COVID19']       False
# 179107                                NaN       False
#
# [179108 rows x 7 columns]

# %%
data_1.groupby(['user_location']).count()
# Out:
#                           user_description  user_verified    date    text  \
# user_location
# Alabama                                179            181     181     181
# Alaska                                  65             65      65      65
# Arizona                                474            491     491     491
# Arkansas                               175            178     178     178
# California                            3879           3998    3998    3998
# Colorado                               452            461     461     461
# Connecticut                            266            270     270     270
# Delaware                                39             40      40      40
# District of Columbia                  1449           1456    1456    1456
# Florida                               1526           1590    1590    1590
# Georgia                                905            933     933     933
# Guam                                     4              4       4       4
# Hawaii                                 187            195     195     195
# Idaho                                   71             75      75      75
# Illinois                               939            984     984     984
# Indiana                                340            371     371     371
# Iowa                                   164            168     168     168
# Kansas                                 102            107     107     107
# Kentucky                               167            174     174     174
# Louisiana                              345            353     353     353
# Maine                                   81             82      82      82
# Maryland                               492            499     499     499
# Massachusetts                          897            911     911     911
# Michigan                               496            510     510     510
# Minnesota                              342            348     348     348
# Mississippi                             87             90      90      90
# Missouri                               370            382     382     382
# Montana                                 40             40      40      40
# Nebraska                               102            106     106     106
# Nevada                                 355            364     364     364
# New Hampshire                          106            106     106     106
# New Jersey                             486            501     501     501
# New Mexico                              96            104     104     104
# New York                              2735           2832    2832    2832
# None                                143471         152934  152934  152934
# North Carolina                         622            635     635     635
# North Dakota                            20             21      21      21
# Northern Mariana Islands                 1              1       1       1
# Ohio                                   640            657     657     657
# Oklahoma                               172            178     178     178
# Oregon                                 424            439     439     439
# Pennsylvania                           716            746     746     746
# Philippine Islands                       1              1       1       1
# Puerto Rico                             13             13      13      13
# Rhode Island                            36             41      41      41
# South Carolina                         244            248     248     248
# South Dakota                            24             25      25      25
# Tennessee                              425            437     437     437
# Texas                                 2047           2128    2128    2128
# Utah                                   181            194     194     194
# Vermont                                 43             46      46      46
# Virgin Islands                           3              5       5       5
# Virginia                               381            390     390     390
# Washington                             622            663     663     663
# West Virginia                           80             82      82      82
# Wisconsin                              230            242     242     242
# Wyoming                                 13             13      13      13
#
#                           hashtags  is_retweet
# user_location
# Alabama                        114         181
# Alaska                          50          65
# Arizona                        331         491
# Arkansas                       135         178
# California                    2819        3998
# Colorado                       316         461
# Connecticut                    190         270
# Delaware                        31          40
# District of Columbia          1034        1456
# Florida                       1115        1590
# Georgia                        713         933
# Guam                             2           4
# Hawaii                         151         195
# Idaho                           42          75
# Illinois                       693         984
# Indiana                        230         371
# Iowa                           114         168
# Kansas                          75         107
# Kentucky                       118         174
# Louisiana                      278         353
# Maine                           55          82
# Maryland                       360         499
# Massachusetts                  664         911
# Michigan                       363         510
# Minnesota                      251         348
# Mississippi                     62          90
# Missouri                       266         382
# Montana                         30          40
# Nebraska                        76         106
# Nevada                         276         364
# New Hampshire                   82         106
# New Jersey                     376         501
# New Mexico                      81         104
# New York                      1975        2832
# None                        109293      152934
# North Carolina                 435         635
# North Dakota                    20          21
# Northern Mariana Islands         0           1
# Ohio                           471         657
# Oklahoma                       123         178
# Oregon                         303         439
# Pennsylvania                   527         746
# Philippine Islands               1           1
# Puerto Rico                     12          13
# Rhode Island                    31          41
# South Carolina                 176         248
# South Dakota                    18          25
# Tennessee                      330         437
# Texas                         1423        2128
# Utah                           125         194
# Vermont                         29          46
# Virgin Islands                   5           5
# Virginia                       284         390
# Washington                     450         663
# West Virginia                   56          82
# Wisconsin                      182         242
# Wyoming                         12          13

# %%
data_2 = data_1[data_1['user_location'] != 'None']

# %%
data_2
# Out:
#        user_location                                   user_description  \
# 1           New York  Husband, Father, Columnist & Commentator. Auth...
# 2           Kentucky  #Christian #Catholic #Conservative #Reagan #Re...
# 6            Florida  Workplace tips and advice served up in a frien...
# 27          New York  These days, I expose colonizers & exploits @ t...
# 32           Florida  We beautify data to learn and gain insight fro...
# ...              ...                                                ...
# 179093   Connecticut  Norwalk Public Library is a public library loc...
# 179095      Michigan  Host of the Morning Wake Up w/Dave Akerly @132...
# 179096    California  Creative Director/AD/CW, Advertising & Brandin...
# 179100    New Jersey  @njherald reporter || chasing crime and coveri...
# 179101    New Jersey  The New Jersey Herald, a daily newspaper in Ne...
#
#         user_verified                 date  \
# 1                True  2020-07-25 12:27:17
# 2               False  2020-07-25 12:27:14
# 6               False  2020-07-25 12:27:03
# 27              False  2020-07-25 12:26:26
# 32              False  2020-07-25 12:26:17
# ...               ...                  ...
# 179093          False  2020-08-29 19:44:48
# 179095          False  2020-08-29 19:44:42
# 179096          False  2020-08-29 19:44:40
# 179100          False  2020-08-29 19:44:27
# 179101          False  2020-08-29 19:44:27
#
#                                                      text  \
# 1       Hey @Yankees @YankeesPR and @MLB - wouldn't it...
# 2       @diane3443 @wdunlap @realDonaldTrump Trump nev...
# 6       How #COVID19 Will Change Work in General (and ...
# 27      I can imagine the same people profiting off th...
# 32      An update on the total #covid19 cases, recover...
# ...                                                   ...
# 179093  What are those #library #cats doing now?  #COV...
# 179095  #COVID19 Update: 23 new cases today in the Tri...
# 179096  We were really bummed we couldn’t cop one of t...
# 179100  Wallkill school nurse adds COVID-19 monitoring...
# 179101  Wallkill school nurse adds COVID-19 monitoring...
#
#                                                  hashtags  is_retweet
# 1                                                     NaN       False
# 2                                             ['COVID19']       False
# 6                               ['COVID19', 'Recruiting']       False
# 27                                            ['COVID19']       False
# 32                                  ['covid19', 'Africa']       False
# ...                                                   ...         ...
# 179093  ['library', 'cats', 'COVID19', 'pandemic', 'co...       False
# 179095                                        ['COVID19']       False
# 179096                                                NaN       False
# 179100    ['nurses', 'COVID19', 'coronavirus', 'schools']       False
# 179101    ['nurses', 'COVID19', 'coronavirus', 'schools']       False
#
# [26174 rows x 7 columns]

# %%
train = data_2.sample(frac = .02)
test = data_2.drop(train.index)
train_new = pd.read_csv("covid19_tweets_train_new.csv")
train_new
# Out:
#       Index user_location                                   user_description  \
# 0     44450  Pennsylvania  Center of emphasis @CHOP_Research informing ch...
# 1     11375      New York  A child of God,wife,mother,sister,aunt,godmoth...
# 2    128634  Pennsylvania                                                NaN
# 3     54732       Georgia  Advanced Practice Registered Nurse working in ...
# 4     65317       Indiana  Local, state and national news from the WFIU n...
# ..      ...           ...                                                ...
# 518   40860         Texas                                it has electrolytes
# 519   69717      Illinois  Building a revolutionary workers party dedicat...
# 520   29486    New Jersey  Connecting People, Connecting Communities   - ...
# 521   53091     Louisiana  Chief BeenBlocked \n#facts and #reason. #noGod...
# 522   63390         Texas                                                NaN
#
#      user_verified                 date  \
# 0            False  2020-07-31 19:19:58
# 1            False  2020-07-25 04:36:37
# 2            False  2020-08-14 04:26:43
# 3            False  2020-08-01 17:50:53
# 4             True  2020-08-02 17:57:00
# ..             ...                  ...
# 518          False  2020-07-29 16:15:08
# 519          False  2020-08-04 06:29:25
# 520          False  2020-07-27 03:50:44
# 521          False  2020-08-01 18:41:04
# 522          False  2020-08-02 19:01:55
#
#                                                   text  is_serious  \
# 0    Our Scientific Director Meredith Matone told @...         1.0
# 1    Give $2000/month to every American #moneyforth...         0.0
# 2    More people died of the seasonal flu in EVERY ...         0.0
# 3    Thanks to @macmillanpages for having me on her...         1.0
# 4    As of today at noon, the @StateHealthIN says 6...         1.0
# ..                                                 ...         ...
# 518  @abc13houston @DrJAshton @ABC Dear #DrAnthonyF...         0.0
# 519  What set off my #bullshitdetector on early #Bo...         0.0
# 520  #COVID19 Dashboard (by State) with Confirmed, ...         1.0
# 521  @RVAwonk @SnowflakeSnark #COVID19 looking for ...         0.0
# 522  @Poetic_line @Scaramucci The top 12 states by ...         1.0
#
#                                               hashtags  is_retweet
# 0                                          ['COVID19']       False
# 1                     ['moneyforthepeople', 'covid19']       False
# 2                                         ['Covid_19']       False
# 3                                          ['COVID19']       False
# 4                                                  NaN       False
# ..                                                 ...         ...
# 518                                 ['DrAnthonyFauci']       False
# 519  ['bullshitdetector', 'BourgeoisPress', 'COVID19']       False
# 520                                        ['COVID19']       False
# 521                                        ['COVID19']       False
# 522                                        ['COVID19']       False
#
# [523 rows x 9 columns]

# %%
stop_words = set(stopwords.words('english')) 
porter = PorterStemmer()

# %%
train_new.text = train_new.text.apply(lambda x: ' '.join([word for word in x.split() if word not in (stop_words)]))

# %%
train_new
# Out:
#       Index user_location                                   user_description  \
# 0     44450  Pennsylvania  Center of emphasis @CHOP_Research informing ch...
# 1     11375      New York  A child of God,wife,mother,sister,aunt,godmoth...
# 2    128634  Pennsylvania                                                NaN
# 3     54732       Georgia  Advanced Practice Registered Nurse working in ...
# 4     65317       Indiana  Local, state and national news from the WFIU n...
# ..      ...           ...                                                ...
# 518   40860         Texas                                it has electrolytes
# 519   69717      Illinois  Building a revolutionary workers party dedicat...
# 520   29486    New Jersey  Connecting People, Connecting Communities   - ...
# 521   53091     Louisiana  Chief BeenBlocked \n#facts and #reason. #noGod...
# 522   63390         Texas                                                NaN
#
#      user_verified                 date  \
# 0            False  2020-07-31 19:19:58
# 1            False  2020-07-25 04:36:37
# 2            False  2020-08-14 04:26:43
# 3            False  2020-08-01 17:50:53
# 4             True  2020-08-02 17:57:00
# ..             ...                  ...
# 518          False  2020-07-29 16:15:08
# 519          False  2020-08-04 06:29:25
# 520          False  2020-07-27 03:50:44
# 521          False  2020-08-01 18:41:04
# 522          False  2020-08-02 19:01:55
#
#                                                   text  is_serious  \
# 0    Our Scientific Director Meredith Matone told @...         1.0
# 1    Give $2000/month every American #moneyforthepe...         0.0
# 2    More people died seasonal flu EVERY YEAR Obama...         0.0
# 3    Thanks @macmillanpages show talk nurse's persp...         1.0
# 4    As today noon, @StateHealthIN says 67,857 peop...         1.0
# ..                                                 ...         ...
# 518  @abc13houston @DrJAshton @ABC Dear #DrAnthonyF...         0.0
# 519  What set #bullshitdetector early #BourgeoisPre...         0.0
# 520  #COVID19 Dashboard (by State) Confirmed, Death...         1.0
# 521  @RVAwonk @SnowflakeSnark #COVID19 looking wind...         0.0
# 522  @Poetic_line @Scaramucci The top 12 states #CO...         1.0
#
#                                               hashtags  is_retweet
# 0                                          ['COVID19']       False
# 1                     ['moneyforthepeople', 'covid19']       False
# 2                                         ['Covid_19']       False
# 3                                          ['COVID19']       False
# 4                                                  NaN       False
# ..                                                 ...         ...
# 518                                 ['DrAnthonyFauci']       False
# 519  ['bullshitdetector', 'BourgeoisPress', 'COVID19']       False
# 520                                        ['COVID19']       False
# 521                                        ['COVID19']       False
# 522                                        ['COVID19']       False
#
# [523 rows x 9 columns]

# %%
def stem_sent(sentence):
    tokens = sentence.split()
    stemmed_tokens = [porter.stem(i) for i in tokens]
    return ' '.join(stemmed_tokens)

train_new.text = train_new.text.apply(stem_sent).str.replace('[^\w\s]','').str.replace('\d+', '').apply(lambda x: ' '.join([word for word in x.split() if word not in (stop_words)]))

# %%
train_new
# Out:
#       Index user_location                                   user_description  \
# 0     44450  Pennsylvania  Center of emphasis @CHOP_Research informing ch...
# 1     11375      New York  A child of God,wife,mother,sister,aunt,godmoth...
# 2    128634  Pennsylvania                                                NaN
# 3     54732       Georgia  Advanced Practice Registered Nurse working in ...
# 4     65317       Indiana  Local, state and national news from the WFIU n...
# ..      ...           ...                                                ...
# 518   40860         Texas                                it has electrolytes
# 519   69717      Illinois  Building a revolutionary workers party dedicat...
# 520   29486    New Jersey  Connecting People, Connecting Communities   - ...
# 521   53091     Louisiana  Chief BeenBlocked \n#facts and #reason. #noGod...
# 522   63390         Texas                                                NaN
#
#      user_verified                 date  \
# 0            False  2020-07-31 19:19:58
# 1            False  2020-07-25 04:36:37
# 2            False  2020-08-14 04:26:43
# 3            False  2020-08-01 17:50:53
# 4             True  2020-08-02 17:57:00
# ..             ...                  ...
# 518          False  2020-07-29 16:15:08
# 519          False  2020-08-04 06:29:25
# 520          False  2020-07-27 03:50:44
# 521          False  2020-08-01 18:41:04
# 522          False  2020-08-02 19:01:55
#
#                                                   text  is_serious  \
# 0    scientif director meredith maton told busi wit...         1.0
# 1    give month everi american moneyforthepeopl cov...         0.0
# 2    peopl die season flu everi year obama presid d...         0.0
# 3    thank macmillanpag show talk nur perspect covi...         1.0
# 4    As today noon statehealthin say peopl indiana ...         1.0
# ..                                                 ...         ...
# 518  abchouston drjashton abc dear dranthonyfauci t...         0.0
# 519  set bullshitdetector earli bourgeoispress repo...         0.0
# 520  covid dashboard bi state confirm death death c...         1.0
# 521  rvawonk snowflakesnark covid look window get r...         0.0
# 522  poetic_lin scaramucci top state covid death pe...         1.0
#
#                                               hashtags  is_retweet
# 0                                          ['COVID19']       False
# 1                     ['moneyforthepeople', 'covid19']       False
# 2                                         ['Covid_19']       False
# 3                                          ['COVID19']       False
# 4                                                  NaN       False
# ..                                                 ...         ...
# 518                                 ['DrAnthonyFauci']       False
# 519  ['bullshitdetector', 'BourgeoisPress', 'COVID19']       False
# 520                                        ['COVID19']       False
# 521                                        ['COVID19']       False
# 522                                        ['COVID19']       False
#
# [523 rows x 9 columns]

# %%
corpus = train_new[['user_location', 'text']]
corpus.index = corpus['user_location']
corpus
# Out:
#               user_location                                               text
# user_location
# Pennsylvania   Pennsylvania  scientif director meredith maton told busi wit...
# New York           New York  give month everi american moneyforthepeopl cov...
# Pennsylvania   Pennsylvania  peopl die season flu everi year obama presid d...
# Georgia             Georgia  thank macmillanpag show talk nur perspect covi...
# Indiana             Indiana  As today noon statehealthin say peopl indiana ...
# ...                     ...                                                ...
# Texas                 Texas  abchouston drjashton abc dear dranthonyfauci t...
# Illinois           Illinois  set bullshitdetector earli bourgeoispress repo...
# New Jersey       New Jersey  covid dashboard bi state confirm death death c...
# Louisiana         Louisiana  rvawonk snowflakesnark covid look window get r...
# Texas                 Texas  poetic_lin scaramucci top state covid death pe...
#
# [523 rows x 2 columns]

# %%
cv = CountVectorizer()
data_tdm = cv.fit_transform(corpus.text)
data_tdm_1 = pd.DataFrame(data_tdm.toarray(), columns = cv.get_feature_names())
data_tdm_1.index = corpus.index

# %%
data_tdm_1
# Out:
#                aap  ab  abati  abc  abchouston  abl  absolut  abu  academi  \
# user_location
# Pennsylvania     0   0      0    0           0    0        0    0        0
# New York         0   0      0    0           0    0        0    0        0
# Pennsylvania     0   0      0    0           0    0        0    0        0
# Georgia          0   0      0    0           0    0        0    0        0
# Indiana          0   0      0    0           0    0        0    0        0
# ...            ...  ..    ...  ...         ...  ...      ...  ...      ...
# Texas            0   0      0    1           1    0        0    0        0
# Illinois         0   0      0    0           0    0        0    0        0
# New Jersey       0   0      0    0           0    0        0    0        0
# Louisiana        0   0      0    0           0    0        0    0        0
# Texas            0   0      0    0           0    0        0    0        0
#
#                accel  ...  youd  young  youtub  yr  zer  zip  zombi  \
# user_location         ...
# Pennsylvania       0  ...     0      0       0   0    0    0      0
# New York           0  ...     0      0       0   0    0    0      0
# Pennsylvania       0  ...     0      0       0   0    0    0      0
# Georgia            0  ...     0      0       0   0    0    0      0
# Indiana            0  ...     0      0       0   0    0    0      0
# ...              ...  ...   ...    ...     ...  ..  ...  ...    ...
# Texas              0  ...     0      0       0   0    0    0      0
# Illinois           0  ...     0      0       0   0    0    0      0
# New Jersey         0  ...     0      0       0   0    0    0      0
# Louisiana          0  ...     0      0       0   0    0    0      0
# Texas              0  ...     0      0       0   0    0    0      0
#
#                ②positivetest  ③case  ④top
# user_location
# Pennsylvania               0      0     0
# New York                   0      0     0
# Pennsylvania               0      0     0
# Georgia                    0      0     0
# Indiana                    0      0     0
# ...                      ...    ...   ...
# Texas                      0      0     0
# Illinois                   0      0     0
# New Jersey                 0      0     0
# Louisiana                  0      0     0
# Texas                      0      0     0
#
# [523 rows x 2910 columns]

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# ### Top Words

# %%
data_tdm_agg = data_tdm_1.groupby(['user_location']).sum()

# %%
data_tdm_agg.sum().sort_values(ascending = False).head(20)
# Out:
# covid         343
# new            37
# test           35
# peopl          34
# amp            32
# coronaviru     30
# case           29
# mask           27
# pandem         26
# us             25
# death          24
# thi            21
# work           21
# like           21
# go             20
# say            20
# we             20
# report         19
# need           19
# die            19
# dtype: int64

# %% [markdown]
# ### Vocabulary

# %%
data_tdm_trans = data_tdm_agg.transpose()

# %%
data_td_null = data_tdm_agg.replace(0, np.nan)
data_td_null
vocab = data_td_null.count(axis = 1).sort_values(ascending = False)
vocab # the more tweets the more unique words - could sample words from each state to compare vocab
# Out:
# user_location
# California                  677
# New York                    535
# Texas                       339
# Florida                     316
# Illinois                    213
# District of Columbia        193
# Oregon                      177
# Georgia                     158
# Arizona                     153
# Pennsylvania                149
# Ohio                        133
# Washington                  132
# Massachusetts               127
# Maryland                    114
# Colorado                    101
# Oklahoma                     98
# Minnesota                    91
# Wisconsin                    88
# Louisiana                    84
# Tennessee                    84
# Nevada                       80
# North Carolina               78
# South Carolina               72
# Michigan                     69
# Connecticut                  66
# Alabama                      65
# Indiana                      64
# New Jersey                   56
# Virginia                     53
# Arkansas                     48
# Hawaii                       45
# Missouri                     37
# Kansas                       35
# Kentucky                     31
# New Hampshire                31
# Nebraska                     23
# West Virginia                23
# Iowa                         22
# Utah                         21
# Maine                        21
# Mississippi                  12
# Northern Mariana Islands     12
# North Dakota                 11
# Delaware                      7
# dtype: int64

# %% [markdown]
# ### Length of Tweets

# %%
corpus_new = corpus.drop(['user_location'], axis = 1)
tweet_count = corpus_new.groupby(['user_location']).count()
total_words = pd.DataFrame(data_td_null.sum(axis = 1))

# %%
total_words
# Out:
#                               0
# user_location
# Alabama                    73.0
# Arizona                   169.0
# Arkansas                   50.0
# California                952.0
# Colorado                  114.0
# Connecticut                71.0
# Delaware                    8.0
# District of Columbia      230.0
# Florida                   363.0
# Georgia                   189.0
# Hawaii                     48.0
# Illinois                  247.0
# Indiana                    70.0
# Iowa                       22.0
# Kansas                     39.0
# Kentucky                   33.0
# Louisiana                  97.0
# Maine                      23.0
# Maryland                  133.0
# Massachusetts             146.0
# Michigan                   76.0
# Minnesota                 103.0
# Mississippi                13.0
# Missouri                   39.0
# Nebraska                   23.0
# Nevada                     91.0
# New Hampshire              31.0
# New Jersey                 59.0
# New York                  716.0
# North Carolina             85.0
# North Dakota               12.0
# Northern Mariana Islands   12.0
# Ohio                      151.0
# Oklahoma                  112.0
# Oregon                    203.0
# Pennsylvania              175.0
# South Carolina             84.0
# Tennessee                  93.0
# Texas                     419.0
# Utah                       24.0
# Virginia                   56.0
# Washington                143.0
# West Virginia              25.0
# Wisconsin                  94.0

# %%
tweet_length = (total_words[0]/tweet_count['text']).sort_values(ascending = False)

# %%
tweet_length
# Out:
# user_location
# Missouri                    13.000000
# Oregon                      12.687500
# Michigan                    12.666667
# Ohio                        12.583333
# West Virginia               12.500000
# Arkansas                    12.500000
# North Carolina              12.142857
# Louisiana                   12.125000
# Hawaii                      12.000000
# Utah                        12.000000
# Northern Mariana Islands    12.000000
# Washington                  11.916667
# Connecticut                 11.833333
# New Jersey                  11.800000
# Wisconsin                   11.750000
# Indiana                     11.666667
# Pennsylvania                11.666667
# Maine                       11.500000
# District of Columbia        11.500000
# Nebraska                    11.500000
# California                  11.469880
# Colorado                    11.400000
# New York                    11.365079
# Florida                     11.343750
# Arizona                     11.266667
# Massachusetts               11.230769
# Oklahoma                    11.200000
# Virginia                    11.200000
# Georgia                     11.117647
# Maryland                    11.083333
# Texas                       11.026316
# Kentucky                    11.000000
# Iowa                        11.000000
# Illinois                    10.739130
# South Carolina              10.500000
# Alabama                     10.428571
# New Hampshire               10.333333
# Tennessee                   10.333333
# Minnesota                   10.300000
# Kansas                       9.750000
# Nevada                       9.100000
# Delaware                     8.000000
# Mississippi                  6.500000
# North Dakota                 6.000000
# dtype: float64

# %% [markdown]
# ## Training Naive Bayes Model

# %%
labels = pd.DataFrame(train_new['is_serious'])
labels.index = data_tdm_1.index

# %%
train_df = pd.concat([labels, data_tdm_1], axis=1).dropna()

# %%
clf = MultinomialNB()
train_col = train_df.drop('is_serious', axis = 1)
train_labels = train_df['is_serious']
clf.fit(train_col, train_labels)
# Out:
# MultinomialNB()

# %%
predictions = pd.DataFrame(clf.predict(train_col), columns = ['predicted'])
predictions.index = train_labels.index
train_labels = pd.DataFrame(train_labels)
p_t = pd.concat([train_labels, predictions], axis=1)

# %%
p_t['correct'] = np.where(p_t['is_serious'] == p_t['predicted'], True, False)

# %%
p_t['correct'].mean()
# Out:
# 0.9980842911877394
